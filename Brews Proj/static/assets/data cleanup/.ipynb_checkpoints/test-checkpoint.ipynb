# %%
from flask import Flask, render_template
from flask.json import jsonify
import json
import pymongo
from bson import json_util
from bson.json_util import dumps
import sys
import os
sys.path.append("static/assets/")
import pandas as pd

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

client = pymongo.MongoClient("localhost", 27017, maxPoolSize=50)
# d = dict((db, [collection for collection in client[db].collection_names()])
#         for db in client.database_names()

#scatter data
db_forscatter = client.Brews
collectionForScatter = db_forscatter["beers"]

cfScatter = list(collectionForScatter.find())

del cfScatter[0]['_id']

cfScatter = json.dumps(cfScatter, default=json_util.default)

print(cfScatter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-775e61e8697d> in <module>
#      21 cfScatter_dict = cfScatter_df.to_dict
#      22
# ---> 23 cfScatter1 = json.dumps(cfScatter_dict, default=json_util.default)
#      24 print(cfScatter1)
#
# ~\Continuum\anaconda3\envs\PythonData\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# ~\Continuum\anaconda3\envs\PythonData\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# ~\Continuum\anaconda3\envs\PythonData\lib\json\encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# ~\Continuum\anaconda3\envs\PythonData\lib\site-packages\bson\json_util.py in default(obj, json_options)
#     855             # shorter string in Python 2.
#     856             return {'$numberDouble': text_type(repr(obj))}
# --> 857     raise TypeError("%r is not JSON serializable" % obj)
#
# TypeError: <bound method DataFrame.to_dict of         ABV                                              Beer  \
# 0     4.50%                                             Amber
# 1     4.20%                                       Purple Haze
# 2     9.30%              Allagash Black - Bourbon Barrel Aged
# 3     6.86%                                   Allagash Blonde
# 4     9.50%                                Allagash Interlude
# 5     5.00%                                    Allagash White
# 6     6.90%  Anderson Valley Wild Turkey Bourbon Barrel Stout
# 7     8.70%                                     Heelch O'Hops
# 8     7.00%                                    Hop Ottin' IPA
# 9     5.00%                                   Summer Solstice
# 10    6.50%                        Avery India Pale Ale (IPA)
# 11    5.20%                                             Karma
# 12   10.40%                                          Maharaja
# 13    7.10%                                        Odio Equum
# 14    5.60%                                      White Rascal
# 15    5.00%                                     Back East Ale
# 16   10.50%                                    Imperial Stout
# 17    6.00%                                            Porter
# 18    7.50%                                       Convergence
# 19    7.20%                                       Declaration
# 20    6.40%                                       Groundswell
# 21    8.50%                                            Salute
# 22    5.00%                           Calico Copper Amber Ale
# 23    9.60%                                 Dorado Double IPA
# 24    7.00%                                       Sculpin IPA
# 25   10.00%     Victory At Sea Coffee Vanilla Imperial Porter
# 26    5.40%                                   1775 Tavern Ale
# 27    5.70%               Lexington Green East India Pale Ale
# 28    5.50%                              Amber Road Amber Ale
# 29    4.90%                              Pamola Xtra Pale Ale
# ..      ...                                               ...
# 438   4.00%                               Wachusett Light IPA
# 439   4.30%                                     Mild At Heart
# 440   9.00%                   Squatters Hop Rising Double IPA
# 441   4.00%                        Wasatch Apricot Hefeweizen
# 442   6.00%                      Wasatch GhostRider White IPA
# 443   4.00%                           Wasatch Polygamy Porter
# 444  11.80%                                         Blasphemy
# 445  11.10%                                  Blithering Idiot
# 446   9.00%                                 Double Simcoe IPA
# 447   5.90%                                   Last Chance IPA
# 448   9.30%                                  Merry Monks' Ale
# 449   6.40%                White Birch Belgian Style Pale Ale
# 450   6.40%                       White Birch Berliner Weisse
# 451   4.20%                         White Birch Crown Of Gold
# 452   7.70%                          White Birch Hooksett Ale
# 453   5.10%                       White Birch Hop Session Ale
# 454   5.20%                            White Birch Hop To Wit
# 455   5.80%                                       Alchemy Ale
# 456   4.30%                          Citra Blonde Summer Brew
# 457   6.70%               Hopside Down India Style Pale Lager
# 458   5.50%                         Marionberry Hibiscus Gose
# 459   5.80%                   Omission Pale Ale (Gluten-Free)
# 460   6.50%                                   Pitch Black IPA
# 461   6.50%                                       4000'er IPA
# 462   6.00%                         Kanc Country Maple Porter
# 463   5.13%                             Old Man Oatmeal Stout
# 464   4.30%                               Pig's Ear Brown Ale
# 465   6.50%                                          Be Hoppy
# 466   5.00%                                     Blonde Cougar
# 467   8.50%                  Hopulence American Double I.P.A.
#
#                              Brewery  Ratings  Score  rAvg
# 0                  Abita Brewing Co.      880     78  3.44
# 1                  Abita Brewing Co.     1585     74  3.22
# 2           Allagash Brewing Company      194     92  4.16
# 3           Allagash Brewing Company       61     90  4.05
# 4           Allagash Brewing Company      664     94  4.22
# 5           Allagash Brewing Company     2477     93  4.17
# 6    Anderson Valley Brewing Company      236     86  3.80
# 7    Anderson Valley Brewing Company      173     86  3.81
# 8    Anderson Valley Brewing Company     1807     90  4.03
# 9    Anderson Valley Brewing Company      725     83  3.69
# 10             Avery Brewing Company     1720     87  3.89
# 11             Avery Brewing Company      637     78  3.42
# 12             Avery Brewing Company     3172     94  4.24
# 13             Avery Brewing Company       97     93  4.23
# 14             Avery Brewing Company     1231     83  3.66
# 15         Back East Brewing Company       13     83  3.69
# 16         Back East Brewing Company       34     88  3.99
# 17         Back East Brewing Company       12     89  4.24
# 18             Backlash Beer Company       40     87  3.91
# 19             Backlash Beer Company       85     83  3.67
# 20             Backlash Beer Company       47     89  4.06
# 21             Backlash Beer Company       31     91  4.19
# 22     Ballast Point Brewing Company      579     86  3.82
# 23     Ballast Point Brewing Company      871     93  4.19
# 24     Ballast Point Brewing Company     4459     98  4.43
# 25     Ballast Point Brewing Company     1909     98  4.40
# 26       Battle Road Brewing Company       17     83  3.69
# 27       Battle Road Brewing Company       12     83  3.66
# 28                Baxter Brewing Co.       86     82  3.61
# 29                Baxter Brewing Co.      131     81  3.55
# ..                               ...      ...    ...   ...
# 438        Wachusett Brewing Company       15     83  3.70
# 439   Wandering Star Brewing Company       29     85  3.82
# 440                 Wasatch Brew Pub      331     86  3.84
# 441                 Wasatch Brew Pub       42     82  3.58
# 442                 Wasatch Brew Pub       38     82  3.62
# 443                 Wasatch Brew Pub      294     75  3.27
# 444          Weyerbacher Brewing Co.      465     88  3.92
# 445          Weyerbacher Brewing Co.     1272     83  3.67
# 446          Weyerbacher Brewing Co.     2083     92  4.10
# 447          Weyerbacher Brewing Co.      337     80  3.52
# 448          Weyerbacher Brewing Co.     1165     87  3.85
# 449              White Birch Brewing      121     80  3.53
# 450              White Birch Brewing      130     84  3.75
# 451              White Birch Brewing       22     81  3.50
# 452              White Birch Brewing      101     87  3.87
# 453              White Birch Brewing       91     85  3.76
# 454              White Birch Brewing       11     83  3.69
# 455  Widmer Brothers Brewing Company       71     81  3.57
# 456  Widmer Brothers Brewing Company      199     82  3.60
# 457  Widmer Brothers Brewing Company       49     86  3.84
# 458  Widmer Brothers Brewing Company      103     78  3.39
# 459  Widmer Brothers Brewing Company      122     80  3.52
# 460  Widmer Brothers Brewing Company      612     86  3.81
# 461            Woodstock Inn Brewery       24     76  3.14
# 462            Woodstock Inn Brewery       63     76  3.28
# 463            Woodstock Inn Brewery       32     78  3.33
# 464            Woodstock Inn Brewery      199     81  3.59
# 465             Wormtown Brewing Co.      175     94  4.27
# 466             Wormtown Brewing Co.       15     83  3.66
# 467             Wormtown Brewing Co.       55     89  4.02
#
# [468 rows x 6 columns]> is not JSON serializable
